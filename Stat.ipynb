# %%
import numpy as np

# %%
Ads=[10,20,30,40,50]
Sale=[10,12,17,19,16]

# %%
corr=np.corrcoef(Ads,Sale)

# %%
corr_value=corr[0,1]

# %%
corr_value
# Out:
# np.float64(0.9944466052196627)

# %%
Vaccine=[100,200,300,400,600]
Result=[50,30,40,50,90]

# %%
corr=np.corrcoef(Vaccine,Result)

# %%
corr_value=corr[0,1]

# %%
corr_value
# Out:
# np.float64(0.7865322982135293)
