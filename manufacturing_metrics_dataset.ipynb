# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("manufacturing_metrics_dataset.csv")
df
# Out:
#    Day  Units_Produced  Defect_Rate  Production_Time  Energy_Consumption  \
# 0    1             500          2.1              8.0                1200
# 1    2             520          1.9              8.2                1250
# 2    3             480          2.5              7.8                1180
# 3    4             550          1.7              8.5                1300
# 4    5             530          2.0              8.3                1270
# 5    6             470          2.8              7.6                1150
# 6    7             560          1.6              8.6                1320
# 7    8             540          1.8              8.4                1290
# 8    9             460          3.0              7.5                1120
# 9   10             570          1.5              8.7                1350
#
#    Downtime
# 0       0.5
# 1       0.4
# 2       0.7
# 3       0.3
# 4       0.4
# 5       0.8
# 6       0.2
# 7       0.3
# 8       0.9
# 9       0.2

# %%
cov_matrix=df.cov()
cov_matrix
# Out:
#                           Day  Units_Produced  Defect_Rate  Production_Time  \
# Day                  9.166667       26.666667    -0.038889         0.222222
# Units_Produced      26.666667     1506.666667   -19.355556        16.244444
# Defect_Rate         -0.038889      -19.355556     0.263222        -0.211556
# Production_Time      0.222222       16.244444    -0.211556         0.176000
# Energy_Consumption  51.666667     2973.333333   -38.300000        32.133333
# Downtime            -0.061111       -9.511111     0.127444        -0.103556
#
#                     Energy_Consumption   Downtime
# Day                          51.666667  -0.061111
# Units_Produced             2973.333333  -9.511111
# Defect_Rate                 -38.300000   0.127444
# Production_Time              32.133333  -0.103556
# Energy_Consumption         5912.222222 -18.788889
# Downtime                    -18.788889   0.062333

# %%
cor_matric=df.corr()
cor_matric
# Out:
#                          Day  Units_Produced  Defect_Rate  Production_Time  \
# Day                 1.000000        0.226910    -0.025036         0.174955
# Units_Produced      0.226910        1.000000    -0.971932         0.997562
# Defect_Rate        -0.025036       -0.971932     1.000000        -0.982894
# Production_Time     0.174955        0.997562    -0.982894         1.000000
# Energy_Consumption  0.221937        0.996230    -0.970872         0.996148
# Downtime           -0.080845       -0.981437     0.994946        -0.988683
#
#                     Energy_Consumption  Downtime
# Day                           0.221937 -0.080845
# Units_Produced                0.996230 -0.981437
# Defect_Rate                  -0.970872  0.994946
# Production_Time               0.996148 -0.988683
# Energy_Consumption            1.000000 -0.978736
# Downtime                     -0.978736  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure()
sns.heatmap(cor_matric,annot=True,cmap="plasma")
plt.title("Correlation Matric in manufacturing")
plt.show()

# %%
df=pd.read_csv("myntra_products_catalog.csv")
df
# Out:
#        ProductID                                        ProductName  \
# 0       10017413  DKNY Unisex Black & Grey Printed Medium Trolle...
# 1       10016283  EthnoVogue Women Beige & Grey Made to Measure ...
# 2       10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...
# 3       10015921  Raymond Men Blue Self-Design Single-Breasted B...
# 4       10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...
# ...          ...                                                ...
# 12486   10262843  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...
# 12487   10261721                 Mochi Women Gold-Toned Solid Heels
# 12488   10261607  612 league Girls Navy Blue & White Printed Reg...
# 12489   10266621  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...
# 12490   10265199  Pepe Jeans Men Black & Grey Striped Polo Colla...
#
#       ProductBrand  Gender  Price (INR)  NumImages  \
# 0             DKNY  Unisex        11745          7
# ...

# %%
xyz=df.sample(n=1000, random_state=42)

# %%
xyz
# Out:
#        ProductID                                        ProductName  \
# 10105   10247147  Flying Machine Boys Blue Regular Fit Mid-Rise ...
# 4667    10134531  Indian Terrain Boys Yellow Printed Round Neck ...
# 7523    10186043  AURELIA Women Mustard Yellow Regular Fit Solid...
# 7420    10186599                 Lavie Orange Textured Shoulder Bag
# 11193   10252497  Genius18 Men White & Navy Blue Printed Hooded ...
# ...          ...                                                ...
# 7772    10178975        Global Desi Navy Blue Textured Shoulder Bag
# 5526    10138367  Indian Terrain Boys Turquoise & Navy Blue Regu...
# 11763   10252837  PUMA Motorsport Unisex Blue Printed Red Bull R...
# 7317    10177629           SG YUVRAJ Boys Blue & Brown Sherwani Set
# 5250    10138679  Indian Terrain Boys Blue Striped Cotton Regula...
#
#           ProductBrand  Gender  Price (INR)  NumImages  \
# 10105   Flying Machine    Boys          749          3
# ...

# %%
abc=df.sample(frac=0.2,random_state=42)
abc
# Out:
#        ProductID                                        ProductName  \
# 10105   10247147  Flying Machine Boys Blue Regular Fit Mid-Rise ...
# 4667    10134531  Indian Terrain Boys Yellow Printed Round Neck ...
# 7523    10186043  AURELIA Women Mustard Yellow Regular Fit Solid...
# 7420    10186599                 Lavie Orange Textured Shoulder Bag
# 11193   10252497  Genius18 Men White & Navy Blue Printed Hooded ...
# ...          ...                                                ...
# 6076    10161227  Indian Terrain Men Black Rust Red Solid Revers...
# 5556    10137271        Puma Unisex Grey Escaper Core Running Shoes
# 10366   10243575   GAP Women V-neck Floral Print Flutter Sleeve Top
# 4617    10129579   Newport Men Off-White Printed Round Neck T-shirt
# 409     10017571  Soie Nude Lace Non-Wired Non Padded full cover...
#
#          ProductBrand  Gender  Price (INR)  NumImages  \
# 10105  Flying Machine    Boys          749          3
# ...

# %%
from scipy.stats import ttest_ind
import numpy as np

# %%
# t-Test
male=df[df["Gender"]=="Men"]["Price (INR)"]
female=df[df["Gender"]=="Women"]["Price (INR)"]

# %%
t_stat,p_value=ttest_ind(male,female)

# %%
print(t_stat,p_value)
# Out:
# 5.7602052995914255 8.65658884544324e-09

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from scipy.stats import norm

# %%
price=df["Price (INR)"]

# %%
sample=price.mean()
avg_price=2000
real_data=price.std(ddof=0)
n=len(price)

# %%
z=(sample-avg_price)/(real_data/np.sqrt(n))
z
# Out:
# np.float64(-28.8764057163605)

# %%
from scipy.stats import chi2_contingency

# %%
con=pd.crosstab(df["ProductBrand"],df["Gender"])

# %%
chi2,p,dof,expected=chi2_contingency(con)
chi2,p
# Out:
# (np.float64(39658.50801851147), np.float64(0.0))
